# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("./data/pg_essay_sm.txt")
docs = loader.load()

# %%
from langchain_experimental.text_splitter import SemanticChunker
from langchain.embeddings import HuggingFaceEmbeddings

text_splitter = SemanticChunker(HuggingFaceEmbeddings())
documents = text_splitter.split_documents(docs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain_experimental.text_splitter import SemanticChunker
#       2 from langchain.embeddings import HuggingFaceEmbeddings
#       4 text_splitter = SemanticChunker(HuggingFaceEmbeddings())
#
# ModuleNotFoundError: No module named 'langchain_experimental'
